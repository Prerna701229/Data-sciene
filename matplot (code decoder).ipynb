# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoint=([0,6])
ypoint=np.array([0,1000])
plt.plot(xpoint,ypoint,'o')
plt.show()

# %%
xpoint=([1,2,5,7])
ypoint=np.array([2,7,9,10])
plt.plot(xpoint,ypoint)
plt.show()

# %%
xpoint=([1,2,5,7])
plt.plot(xpoint,'D')
plt.show()

# %%
ypoint=([2,5,7,10])
plt.plot(ypoint,'*')
plt.show()

# %%
xpoint=([1,2,5,7])
plt.plot(xpoint,'o:r')
plt.show()

# %%
xpoint=([1,2,5,7])
plt.plot(xpoint,'o-y')
plt.show()

# %%
xpoint=([1,2,5,7])
plt.plot(xpoint,marker='o',ms=20,mec='r')
plt.show()

# %%
xpoint=([1,2,5,7])
plt.plot(xpoint,marker='o',ms=20,mfc='r',mec='r')
plt.show()

# %%
xpoint=([1,2,5,7])
plt.plot(xpoint,linestyle='dotted')
plt.show()

# %%
xpoint=([1,2,5,7])
plt.plot(xpoint,linestyle='dashed',color='green')
plt.show()

# %%
xpoint=([1,2,5,7])
plt.plot(xpoint,ls=':',color='r')
plt.show()

# %%
xpoint=([1,2,5,7])
plt.plot(xpoint,ls=':',color='r',linewidth=20)
plt.show()

# %%
xpoint=([1,5,7,9])
ypoint=np.array([3,8,4,6])
plt.plot(xpoint)
plt.plot(ypoint)
plt.show()

# %%
xpoint=np.array([1,5,7,9])
ypoint=np.array([3,8,4,6])
plt.plot(xpoint,ypoint)
font1={'color':'blue','size':20}
font2={'color':'red','size':30}
plt.title("Tournament" ,fontdict=font2 ,loc='left')
plt.xlabel("Cricket" ,fontdict=font1)
plt.ylabel("Hockey" ,fontdict=font1)
plt.grid(color='red',linestyle='--',linewidth=1)
plt.show()

# %%
xpoint=np.array([1,5,6,4])
ypoint=np.array([9,6,8,2])
plt.subplot(1,2,1)
plt.plot(xpoint,ypoint)

xpoint=np.array([2,8,3,4])
ypoint=np.array([97,2,5,2])
plt.subplot(1,2,2)
plt.plot(xpoint,ypoint)

plt.show()

# %%
xpoint=np.array([1,5,6,4])
ypoint=np.array([9,6,8,2])
plt.subplot(2,2,1)
plt.plot(xpoint,ypoint)

xpoint=np.array([2,8,3,4])
ypoint=np.array([97,2,5,2])
plt.subplot(2,2,2)
plt.plot(xpoint,ypoint)

plt.show()

# %%
xpoint=np.array([1,5,6,4])
ypoint=np.array([9,6,8,2])
plt.subplot(2,3,1)
plt.plot(xpoint,ypoint)

xpoint=np.array([2,8,3,4])
ypoint=np.array([97,2,5,2])
plt.subplot(2,3,2)
plt.plot(xpoint,ypoint)

xpoint=np.array([1,5,6,4])
ypoint=np.array([9,6,8,2])
plt.subplot(2,3,3)
plt.plot(xpoint,ypoint)

xpoint=np.array([2,8,3,4])
ypoint=np.array([97,2,5,2])
plt.subplot(2,3,4)
plt.plot(xpoint,ypoint)

xpoint=np.array([1,5,6,4])
ypoint=np.array([9,6,8,2])
plt.subplot(2,3,5)
plt.plot(xpoint,ypoint)

xpoint=np.array([2,8,3,4])
ypoint=np.array([97,2,5,2])
plt.subplot(2,3,6)
plt.plot(xpoint,ypoint)
plt.title('Cricket')

plt.suptitle("Games")
plt.show()

# %%
x=np.array(["Apple","Orange","Mango","Banana"])
y=np.array([3,7,9,1])
plt.bar(x,y)
plt.show()

# %%
x=np.array(["Apple","Orange","Mango","Banana"])
y=np.array([3,7,9,1])
plt.barh(x,y)
plt.show()

# %%
x=np.array(["Apple","Orange","Mango","Banana"])
y=np.array([3,7,9,1])
plt.bar(x,y,color="red")
plt.show()

# %%
x=np.array(["Apple","Orange","Mango","Banana"])
y=np.array([3,7,9,1])
plt.bar(x,y,color="green",width=2)
plt.show()

# %%
x=np.array(["Apple","Orange","Mango","Banana"])
y=np.array([3,7,9,1])
plt.barh(x,y,color="yellow",height=2)
plt.show()

# %%
x=np.array(["Apple","Orange","Mango","Banana"])
plt.hist(x)
plt.show()

# %%
y=np.random.normal(170,10,250)
plt.hist(y)
plt.show()

# %%
y=np.array([3,7,9,1])
plt.pie(y)
plt.show()

# %%
y=np.array([3,7,9,1])
a=["apple","banana","orange","lichi"]
plt.pie(y,labels=a)
plt.show()

# %%
y=np.array([3,7,9,1])
a=["apple","banana","orange","lichi"]
plt.pie(y,labels=a,startangle=90)
plt.show()

# %%
y=np.array([3,7,9,1])
a=["apple","banana","orange","lichi"]
b=[0.6,0,0.4,0]
plt.pie(y,labels=a,startangle=90,explode=b,shadow=True)
plt.show()

# %%
y=np.array([3,7,9,1])
a=["apple","banana","orange","lichi"]
b=[0.6,0,0.4,0]
c=["red","yellow","orange","pink"]
plt.pie(y,labels=a,startangle=90,explode=b,shadow=True,colors=c)
plt.show()

# %%
y=np.array([3,7,9,1])
a=["apple","banana","orange","lichi"]
b=[0.6,0,0.4,0]
c=["red","yellow","orange","pink"]
plt.pie(y,labels=a,startangle=90,explode=b,shadow=True,colors=c)
plt.legend(title="Fruits")
plt.show()

# %%
x=np.array([4,6,7,8,9,2])
y=np.array([30,73,90,1,80,20])
plt.scatter(x,y)
plt.show()

# %%
x=np.array([4,6,7,8,9,2])
y=np.array([30,73,90,1,80,20])
plt.scatter(x,y,color="green")

x=np.array([40,60,71,82,93,24])
y=np.array([32,74,96,12,85,25])
plt.scatter(x,y,color="yellow")

plt.show()

# %%
x=np.array([4,6,7,8,9,2])
y=np.array([30,73,90,1,80,20])
plt.scatter(x,y)

x=np.array([40,60,71,82,93,24])
y=np.array([32,74,96,12,85,25])
color=np.array(["red","blue","pink","green","orange","black"])
plt.scatter(x,y,c=color)

plt.show()

# %%
x=np.array([35,89,10,36,78,52,45,10])
y=np.array([3,7,9,1,8,6,7,4])
plt.scatter(x,y,cmap="virdis")
plt.colorbar()
plt.show()

# %%
x=np.array([35,89,10,36,78,52,45,10])
y=np.array([3,7,9,1,8,6,7,4])
size=np.array([20,100,500,300,150,550,250,90])
plt.scatter(x,y,s=size,alpha=0.5)
plt.colorbar()
plt.show()

# %%
x=np.random.randint(100,size=(100))
y=np.random.randint(100,size=(100))
color=np.random.randint(100,size=(100))
size=5*np.random.randint(100,size=(100))
plt.scatter(x,y,c=color,s=size,alpha=0.5,cmap="nipy_spectral")
plt.colorbar()
plt.show()

# %%
import pandas as pd

# %%
df=pd.read_csv()
