# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
a=pd.read_csv("hospitals.csv")

# %%
print(a)
# Out:
#                                          Facility.Name  Facility.City  \
# 0                     Southeast Alabama Medical Center         Dothan
# 1                        Marshall Medical Center South           Boaz
# 2                       Eliza Coffee Memorial Hospital       Florence
# 3                             Mizell Memorial Hospital            Opp
# 4                          Crenshaw Community Hospital        Luverne
# ...                                                ...            ...
# 4767          Providence Hospital Of North Houston Llc        Houston
# 4768  The Hospitals Of Providence Transmountain Campus        El Paso
# 4769                     Saint Camillus Medical Center          Hurst
# 4770          Houston Methodist The Woodlands Hospital  The Woodlands
# 4771   The Hospitals Of Providence Horizon City Campus   Horizon City
#
#      Facility.State Facility.Type  Rating.Overall Rating.Mortality  \
# ...

# %%
a.head()
# Out:
#                       Facility.Name Facility.City Facility.State  \
# 0  Southeast Alabama Medical Center        Dothan             AL
# 1     Marshall Medical Center South          Boaz             AL
# 2    Eliza Coffee Memorial Hospital      Florence             AL
# 3          Mizell Memorial Hospital           Opp             AL
# 4       Crenshaw Community Hospital       Luverne             AL
#
#   Facility.Type  Rating.Overall Rating.Mortality Rating.Safety  \
# 0    Government               2            Below         Above
# 1    Government               1            Below         Below
# 2    Government               3            Below         Above
# 3       Private               1             Same          Same
# 4   Proprietary               4             Same          None
#
#   Rating.Readmission Rating.Experience Rating.Effectiveness  ...  \
# 0              Below             Below                 Same  ...
# ...

# %%
a.tail()
# Out:
#                                          Facility.Name  Facility.City  \
# 4767          Providence Hospital Of North Houston Llc        Houston
# 4768  The Hospitals Of Providence Transmountain Campus        El Paso
# 4769                     Saint Camillus Medical Center          Hurst
# 4770          Houston Methodist The Woodlands Hospital  The Woodlands
# 4771   The Hospitals Of Providence Horizon City Campus   Horizon City
#
#      Facility.State Facility.Type  Rating.Overall Rating.Mortality  \
# 4767             TX   Proprietary              -1             None
# 4768             TX   Proprietary              -1             None
# 4769             TX   Proprietary              -1             None
# 4770             TX       Private               3             None
# 4771             TX   Proprietary              -1             None
#
#      Rating.Safety Rating.Readmission Rating.Experience Rating.Effectiveness  \
# ...

# %%
a.tail(10)
# Out:
#                                          Facility.Name  Facility.City  \
# 4762                     Humble Surgical Hospital, Llc         Humble
# 4763                      Cleveland Emergency Hospital      Cleveland
# 4764                                Wise Health System     Fort Worth
# 4765                  Texas General Hospital- Vzrmc Lp   Grand Saline
# 4766                              First Texas Hospital        Houston
# 4767          Providence Hospital Of North Houston Llc        Houston
# 4768  The Hospitals Of Providence Transmountain Campus        El Paso
# 4769                     Saint Camillus Medical Center          Hurst
# 4770          Houston Methodist The Woodlands Hospital  The Woodlands
# 4771   The Hospitals Of Providence Horizon City Campus   Horizon City
#
#      Facility.State Facility.Type  Rating.Overall Rating.Mortality  \
# 4762             TX       Unknown              -1             None
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4772 entries, 0 to 4771
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Facility.Name                    4772 non-null   object
#  1   Facility.City                    4772 non-null   object
#  2   Facility.State                   4772 non-null   object
#  3   Facility.Type                    4772 non-null   object
#  4   Rating.Overall                   4772 non-null   int64
#  5   Rating.Mortality                 4772 non-null   object
#  6   Rating.Safety                    4772 non-null   object
#  7   Rating.Readmission               4772 non-null   object
#  8   Rating.Experience                4772 non-null   object
#  9   Rating.Effectiveness             4772 non-null   object
#  10  Rating.Timeliness                4772 non-null   object
#  11  Rating.Imaging                   4772 non-null   object
# ...

# %%
a.corr()
# Out:
#                               Rating.Overall  Procedure.Heart Attack.Cost  \
# Rating.Overall                      1.000000                     0.348365
# Procedure.Heart Attack.Cost         0.348365                     1.000000
# Procedure.Heart Failure.Cost        0.604410                     0.598840
# Procedure.Pneumonia.Cost            0.509664                     0.450954
# Procedure.Hip Knee.Cost             0.437272                     0.608347
#
#                               Procedure.Heart Failure.Cost  \
# Rating.Overall                                    0.604410
# Procedure.Heart Attack.Cost                       0.598840
# Procedure.Heart Failure.Cost                      1.000000
# Procedure.Pneumonia.Cost                          0.686247
# Procedure.Hip Knee.Cost                           0.520623
#
#                               Procedure.Pneumonia.Cost  \
# Rating.Overall                                0.509664
# ...

# %%
a['Rating.Overall'].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>
